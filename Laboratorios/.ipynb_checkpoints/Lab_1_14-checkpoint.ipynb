# %% [markdown]
# <img src="Archivos/miia.jpg" width=800x>
#
# # Laboratorio 1
#
# ## Desarrollo de una herramienta analítica usando solo Python
#
# Este laboratorio busca evaluar las habilidades relacionadas con la primera parte del curso, correspondiente a las primeras tres semanas. Este enunciado estará disponible desde la semana 2 y deberá entregarse al final de la semana 4 en el enlace correspondiente. Su desarrollo corresponde al 30% de la calificación total del curso.
#
# Esta actividad responde directamente al segundo objetivo del curso:
# * Implementar una herramienta analítica que permita responder una pregunta de negocio para un problema sencillo de analítica de datos, utilizando únicamente algorítmica básica en Python.
#
# Al desarrollar este laboratorio pondrás a prueba tus habilidades para:
# 1. Leer datos desde archivos.
# 2. Almacenar datos en  estructuras de Python.
# 3. Crear y llamar funciones correctamente.
# 4. Implementar condicionales diferenciando *if*, *elif* y *else*
# 5. Implementar ciclos diferenciando el propósito de *for* y *while*
# 6. Importar paquetes y utilizar sus funciones.
#
# **NOTAS:**
# - Te recomendamos leer por completo el enunciado del laboratorio antes de comenzar, de forma que tengas claro el propósito completo de la actividad, y puedas desarrollar tu solución apuntando a él desde el comienzo.

# %% [markdown]
# ## Contexto: exploración del potencial para asignar becas Uniandes
# La Universidad de los Andes se ha caracterizado por su compromiso con la generación de impacto en la sociedad a través de diferentes programas de becas. Programas como Quiero Estudiar, o Ser Pilo Paga, entre otros, han sido revolucionarios, al permitir que estudiantes de bajos recursos puedan acceder a una de las universidades privadas más importantes del país.
#
# Actualmente, la Universidad quiere evaluar el potencial impacto que tendrían algunos programas de *acción afirmativa* para asignación de becas, con base en información demográfica que ha obtenido a través de encuestas. Se cuenta con información respecto a la edad, género, estado civil, estrato socio-económico, región de proveniencia, desempeño académico y nivel de escolaridad de las personas que han respondido encuestas. Los encargados de diseñar el programa saben que utilizar criterios basados en este tipo de variables es un tema sensible, pero es necesario si se quieren focalizar las oportunidades en poblaciones menos representadas.
#
# El objetivo de este laboratorio es crear una herramienta computacional que permita a un tomador de decisiones explorar qué efecto podría tener el uso de diferentes reglas para seleccionar la población que sería beneficiaria de las becas. Puntualmente, se espera que, dadas unas reglas de selección (ej.: pertenecer a cierta región, rango de edad, etc.), la herramienta ofrezca información sobre la población potencialmente beneficiada, de forma que exista un sustento al momento de definir las reglas de selección.

# %% [markdown]
# ## 1. Obtención e inspección de archivos
#
# Los datos de encuestas fueron obtenidos como parte de un trabajo de campo, y por limitaciones tecnológicas, solo se cuenta con la información en archivos de texto plano. Cada archivo corresponde a una de las variables antes mencionadas y se puede garantizar que todos relacionan a las personas encuestadas en el mismo orden (i.e., la primera línea de todos los archivos corresponde a datos de la primera persona encuestada, la segunda línea a la segunda persona, etc.).
#
# Los archivos con los que se cuenta son:
# * *edades.txt*: un archivo ordenado con las edades de cada persona de la población encuestada
# * *género.txt*: un archivo ordenado con el género de cada persona de la población encuestada
# * *estado_civil.txt*: un archivo ordenado con el estado civil de cada persona de la población encuestada
# * *escolaridad.txt*: un archivo ordenado con el nivel de escolaridad de cada persona de la población encuestada
# * *estrato.txt*: un archivo ordenado con el estrato socio-económico de cada persona de la población encuestada
# * *region.txt*: un archivo ordenado con la región de proveniencia de cada persona de la población encuestada

# %% [markdown]
# **Misión 1**
#
# Poner en variables de Python la información que está en los archivos listados arriba.
#
# * *Versión base*: escribe línea a línea el código necesario para poner en variables de Python la información de cada uno de los archivos.
#
# * *Milla extra*: escribe una función que sea capaz de hacer lo anterior para un archivo y úsala en un ciclo para automatizar la lectura de los diferentes archivos.

# %%
# código
def abrir_archivos(archivo):
    lista = []
    f = open(archivo,"r", encoding = 'UTF-8')
    lista = f.read().splitlines()
    f.close()
    return lista 

import os
archivos = os.listdir('C:\\Users\\javie\\OneDrive - Universidad de los Andes\\Documentos\\Maestría Analytics\\1er semestre\\Herramientas Computacionales Para Análisis de Datos\\MIIA_estudiante_14\\Laboratorios')

for i in archivos:
    if i == "edad.txt":
        edadarchivo = abrir_archivos(i)
        edad =[]
        for j in edadarchivo:
            edad.append(int(j))
    elif i == "genero.txt":
        genero = abrir_archivos(i)
    elif i == "estado_civil.txt":
        estado_civil = abrir_archivos(i)
    elif i == "escolaridad.txt":
        escolaridad = abrir_archivos(i)
    elif i == "estrato.txt":
        estratoarchivo  = abrir_archivos(i)
        estrato = []
        for k in estratoarchivo:
            estrato.append(int(k))
    elif i == "region.txt":
        region = abrir_archivos(i)
    elif i == "promedio.txt":
        promedioarchivo = abrir_archivos(i)
        promedio = []
        for l in promedioarchivo:
            promedio.append(float(l))

# %% [markdown]
# **Misión 2**
#
# Reportar las principales características en los datos.
# * *Versión base*: utilizar métricas básicas como conteos o promedios por categorías en los datos.
# * *Milla extra*: utilizar visualizaciones simples como diagramas de barras, de pastel u otros.

# %%
# código

# importación de paquetes necesarios
import matplotlib.pyplot as plt
import statistics as st
import math as mt

# función que calcula la mediana de una lista de datos numéricos
def mediana(lista):
    
    if type(lista[1]) is str:
        return print("Esta lista no es numérica")
    
    else:
        ordenada = sorted(lista)
        largo = len(lista)
        valor_medio = (largo-1)//2

        if largo%2 == 0:
            mediana = ordenada[valor_medio]
        else:
            mediana = (ordenada[valor_medio] + ordenada[valor_medio+1]) /2

        return mediana

# función que calcula la desviación de una lista de datos numéricos
def desvest(lista):
    
    if type(lista[1]) is str:
        return print("Esta lista no es numércia")
    
    else:
        largo = len(lista)
        promedio = sum(lista)/largo
        varianza = sum([((i - promedio)**2) for i in lista]) / largo
        desvest = mt.sqrt(varianza)
        
        return desvest

def moda(lista):
    
    moda = st.mode(lista)
    
    return moda


def estadisticas_estrato(lista1,lista2):
    c1estratos = []
    for i in lista1:
        c1estratos.append(i[2])
    c2estratos = []
    for i in lista2:
        c2estratos.append(i[2]) 
        
    mediana1 = mediana(c1estratos)
    mediana2 = mediana(c2estratos)
    desvest1 = desvest(c1estratos)
    desvest2 = desvest(c2estratos)
    moda1 = moda(c1estratos)
    moda2 = moda(c2estratos)
    print("A continuación se muestran los valores estadísticos para la variable estrato según las dos políticas")
    print("")
    print("Primera política:")
    print("Mediana: " + str(mediana1))
    print("Desviación estándar: "+str(desvest1))
    print("Moda: "+str(desvest1))
    print("")
    print("Segunda política:")
    print("Mediana: " + str(mediana2))
    print("Desviación estándar: "+str(desvest2))
    print("Moda: "+str(desvest2))

def estadisticas_edad(lista1,lista2):
    c1estratos = []
    for i in lista1:
        c1estratos.append(i[0])
    c2estratos = []
    for i in lista2:
        c2estratos.append(i[0]) 
        
    mediana1 = mediana(c1estratos)
    mediana2 = mediana(c2estratos)
    desvest1 = desvest(c1estratos)
    desvest2 = desvest(c2estratos)
    moda1 = moda(c1estratos)
    moda2 = moda(c2estratos)
    print("A continuación se muestran los valores estadísticos para la variable edad según las dos políticas")
    print("")
    print("Primera política:")
    print("Mediana: " + str(mediana1))
    print("Desviación estándar: "+str(desvest1))
    print("Moda: "+str(moda1))
    print("")
    print("Segunda política:")
    print("Mediana: " + str(mediana2))
    print("Desviación estándar: "+str(desvest2))
    print("Moda: "+str(moda2))
    
def barras_estrato(lista1,lista2):
    fig, ax = plt.subplots()                                # Declaramos la visualización.
    etiquetas = ['1', '2', '3', '4', '5']                   # Declaramos las etiquetas del eje x (estrato).
    E1C1=0
    E2C1=0
    E3C1=0
    E4C1=0
    E5C1=0
    for i in lista1:
        if i[2] == 1:
            E1C1=E1C1+1
        if i[2] == 2:
            E2C1=E2C1+1
        if i[2] == 3:
            E3C1=E3C1+1
        if i[2] == 4:
            E4C1=E4C1+1
        if i[2] == 5:
            E5C1=E5C1+1
    E1C2=0
    E2C2=0
    E3C2=0
    E4C2=0
    E5C2=0
    for i in lista2:
        if i[2] == 1:
            E1C2=E1C2+1
        if i[2] == 2:
            E2C2=E2C2+1
        if i[2] == 3:
            E3C2=E3C2+1
        if i[2] == 4:
            E4C2=E4C2+1
        if i[2] == 5:
            E5C2=E5C2+1
    Politica_1 = [E1C1, E2C1, E3C1, E4C1, E5C1]        # Declaramos los registros de las ventas del producto A.
    Politica_2 = [E1C2, E2C2, E3C2, E4C2, E5C2]        # Declaramos los registros de las ventas del producto B.
    
    ancho = 0.35                                            # Definimos el ancho de las barras.
    pos_bar_a = [i - ancho/2 for i in range(len(etiquetas))]# Ubicación de cada barra en A.
    pos_bar_b = [i + ancho/2 for i in range(len(etiquetas))]# Ubicación de cada barra en B.
    
    # Serie de datos correspondiente al producto A.
    serie_a = ax.bar(pos_bar_a,                             # Definimos la ubicación de cada barra.
                 Politica_1,                            # Asignamos los registros correspondientes a las barras.
                 ancho,                                 # Asignamos el ancho de cada barra.
                 label = 'Politica 1',                  # Definimos un nombre para la serie A.
                 color = 'lightsteelblue')  
    # Serie de datos correspondiente al producto B.
    serie_b = ax.bar(pos_bar_b,                             # Definimos la ubicación de cada barra.
                 Politica_2,                            # Asignamos los registros del producto A a las barras.
                 ancho,                                 # Asignamos el ancho de cada barra.
                 label = 'Politica 2',                  # Definimos un nombre para la serie A.
                 color = 'navy')                        # Modificamos el color de las barras.
    ax.set_xticks([*range(len(etiquetas))])                 # Establecemos cuales valores del eje x tendrán una etiqueta.
    ax.set_xticklabels(etiquetas)                           # Establecemos las etiquetas del eje x.
    ax.legend()                                             # Declaramos la leyenda de los datos.
    ax.set_title("Comparación estrato")
    
    grafica = plt.show()    
    return grafica

def barras_region(lista1,lista2):
    fig, ax = plt.subplots()                                # Declaramos la visualización.
    etiquetas = ['Andina', 'Pacífica', 'Orinoquía', 'Amazonía', 'Caribe']                   # Declaramos las etiquetas del eje x (estrato).
    E1C1=0
    E2C1=0
    E3C1=0
    E4C1=0
    E5C1=0
    for i in lista1:
        if i[6] == "Andina":
            E1C1=E1C1+1
        if i[6] == "Pacifica":
            E2C1=E2C1+1
        if i[6] == "Orinoquia":
            E3C1=E3C1+1
        if i[6] == "Amazonia":
            E4C1=E4C1+1
        if i[6] == "Caribe":
            E5C1=E5C1+1
    E1C2=0
    E2C2=0
    E3C2=0
    E4C2=0
    E5C2=0
    for i in lista2:
        if i[6] == "Andina":
            E1C2=E1C2+1
        if i[6] == "Pacifica":
            E2C2=E2C2+1
        if i[6] == "Orinoquia":
            E3C2=E3C2+1
        if i[6] == "Amazonia":
            E4C2=E4C2+1
        if i[6] == "Caribe":
            E5C2=E5C2+1
    Politica_1 = [E1C1, E2C1, E3C1, E4C1, E5C1]        # Declaramos los registros de las ventas del producto A.
    Politica_2 = [E1C2, E2C2, E3C2, E4C2, E5C2]        # Declaramos los registros de las ventas del producto B.
    
    ancho = 0.35                                            # Definimos el ancho de las barras.
    pos_bar_a = [i - ancho/2 for i in range(len(etiquetas))]# Ubicación de cada barra en A.
    pos_bar_b = [i + ancho/2 for i in range(len(etiquetas))]# Ubicación de cada barra en B.
    
    # Serie de datos correspondiente al producto A.
    serie_a = ax.bar(pos_bar_a,                             # Definimos la ubicación de cada barra.
                 Politica_1,                            # Asignamos los registros correspondientes a las barras.
                 ancho,                                 # Asignamos el ancho de cada barra.
                 label = 'Politica 1',                  # Definimos un nombre para la serie A.
                 color = 'lightgreen')  
    # Serie de datos correspondiente al producto B.
    serie_b = ax.bar(pos_bar_b,                             # Definimos la ubicación de cada barra.
                 Politica_2,                            # Asignamos los registros del producto A a las barras.
                 ancho,                                 # Asignamos el ancho de cada barra.
                 label = 'Politica 2',                  # Definimos un nombre para la serie A.
                 color = 'green')                        # Modificamos el color de las barras.
    ax.set_xticks([*range(len(etiquetas))])                 # Establecemos cuales valores del eje x tendrán una etiqueta.
    ax.set_xticklabels(etiquetas)                           # Establecemos las etiquetas del eje x.
    ax.legend()                                             # Declaramos la leyenda de los datos.
    ax.set_title("Comparación región")
    
    grafica = plt.show()    
    return grafica


def barras_genero(lista1,lista2):
    fig, ax = plt.subplots()                                # Declaramos la visualización.
    etiquetas = ['Femenino', 'Masculino', 'No binario', 'Otro']                   # Declaramos las etiquetas del eje x (estrato).
    E1C1=0
    E2C1=0
    E3C1=0
    E4C1=0
    E5C1=0
    for i in lista1:
        if i[3] == "femenino":
            E1C1=E1C1+1
        if i[3] == "masculino":
            E2C1=E2C1+1
        if i[3] == "no binario":
            E3C1=E3C1+1
        if i[3] == "otro":
            E4C1=E4C1+1

    E1C2=0
    E2C2=0
    E3C2=0
    E4C2=0
    E5C2=0
    for i in lista2:
        if i[3] == "femenino":
            E1C2=E1C2+1
        if i[3] == "masculino":
            E2C2=E2C2+1
        if i[3] == "no binario":
            E3C2=E3C2+1
        if i[3] == "otro":
            E4C2=E4C2+1

    Politica_1 = [E1C1, E2C1, E3C1, E4C1]        # Declaramos los registros de las ventas del producto A.
    Politica_2 = [E1C2, E2C2, E3C2, E4C2]        # Declaramos los registros de las ventas del producto B.
    
    ancho = 0.35                                            # Definimos el ancho de las barras.
    pos_bar_a = [i - ancho/2 for i in range(len(etiquetas))]# Ubicación de cada barra en A.
    pos_bar_b = [i + ancho/2 for i in range(len(etiquetas))]# Ubicación de cada barra en B.
    
    # Serie de datos correspondiente al producto A.
    serie_a = ax.bar(pos_bar_a,                             # Definimos la ubicación de cada barra.
                 Politica_1,                            # Asignamos los registros correspondientes a las barras.
                 ancho,                                 # Asignamos el ancho de cada barra.
                 label = 'Politica 1',                  # Definimos un nombre para la serie A.
                 color = 'black')  
    # Serie de datos correspondiente al producto B.
    serie_b = ax.bar(pos_bar_b,                             # Definimos la ubicación de cada barra.
                 Politica_2,                            # Asignamos los registros del producto A a las barras.
                 ancho,                                 # Asignamos el ancho de cada barra.
                 label = 'Politica 2',                  # Definimos un nombre para la serie A.
                 color = 'yellow')                        # Modificamos el color de las barras.
    ax.set_xticks([*range(len(etiquetas))])                 # Establecemos cuales valores del eje x tendrán una etiqueta.
    ax.set_xticklabels(etiquetas)                           # Establecemos las etiquetas del eje x.
    ax.legend()                                             # Declaramos la leyenda de los datos.
    ax.set_title("Comparación genero")
    
    grafica = plt.show()    
    return grafica

def hist_edad(lista1, numero_política):
                                    # Declaramos la visualización.
    etiquetas = ['Edad']                   # Declaramos las etiquetas del eje x (estrato).
    c1edad = []
    for i in lista1:
        c1edad.append(i[0])
    
    plt.hist(c1edad) 
    plt.title("Histograma edad política "+str(numero_política))
    plt.ylabel("Becados")
    plt.xlabel("Edad")
    plt.show
    return 

def hist_promedio(lista1,numero_política):
                                    # Declaramos la visualización.
    etiquetas = ['Promedio']                   # Declaramos las etiquetas del eje x (estrato).
    c1edad = []
    for i in lista1:
        c1edad.append(i[1])
    
    plt.hist(c1edad) 
    plt.title("Histograma promedio política "+str(numero_política))
    plt.ylabel("Becados")
    plt.xlabel("Promedio")
    x = plt.show
    return x

def graficas(lista1, lista2):
    grafica1 = barras_estrato(lista1, lista2)
    grafica2 = barras_genero(lista1, lista2)
    grafica3 = barras_region(lista1, lista2)

    return grafica1, grafica2, grafica3

# %% [markdown]
# ## 2. Abordaje de la pregunta de negocio
#
# El comité encargado de diseñar el programa de becas ha tenido dificultades para llegar a acuerdos. Algunos piensan que el criterio principal de selección debería ser respecto a lo económico y académico, sin importar otras características personales, mientras que otros piensan que considerar estas características es, de hecho, parte del espíritu del programa.
#
# * El primer grupo sugiere que se deben tomar en orden ascendente los estratos y elegir, en cada uno de ellos, al 2% de personas con promedio académico superior en esa sub-población, hasta que se agoten las becas disponibles. En caso de quedar becas disponibles al final del proceso, se repite el mismo esquema, considerando que ya no se tienen en cuenta las personas que hayan sido elegidas en rondas anteriores.
#
# * El segundo grupo sugiere que los recibidores de becas deben estar igualmente distribuidos entre las diferentes regiones y generos, considerando, por supuesto, que para cada una de esas sub-poblaciones, las personas elegidas sean las de mejores promedios académicos.
#
# Dado que las diferencias entre estos grupos obedecen a su entendimiento particular del problema, el presidente del comité propone utilizar los datos disponibles de las encuestas, sugiriendo que se analice qué características tendría la población de elegidos bajo cada uno de los dos criterios expuestos.

# %% [markdown]
# **Misión 3**
#
# Defina la pregunta de negocio y la pregunta de *analytics* para esta situación.

# %%
# respuesta en texto (solo leeremos los primeros 300 caracteres de la respuesta)

pregunta_negocio = 'Con base en la información demográfica recolectada por la Universidad de los Andes, ¿cual política de asignación de becas puede generar un mayor impacto en la sociedad colombiana?'

pregunta_analytics = '¿Cuales métricas se utilizarán para evaluar el impacto de las políticas de asignación de becas? ¿Qué métodos se utilizarán para recrear las políticas en lenguaje de programación que permitan ver los estudiantes becados de forma clara y sencilla?'

print(pregunta_negocio)
print("")
print(pregunta_analytics)
# Out:
# Con base en la información demográfica recolectada por la Universidad de los Andes, ¿cual política de asignación de becas puede generar un mayor impacto en la sociedad colombiana?
#
# ¿Cuales métricas se utilizarán para evaluar el impacto de las políticas de asignación de becas? ¿Qué métodos se utilizarán para recrear las políticas en lenguaje de programación que permitan ver los estudiantes becados de forma clara y sencilla?

# %% [markdown]
# **Misión 4**
#
# Desarrollar un algoritmo que permita conocer la población que sería becada según los criterios propuestos por el *primer grupo* mencionado arriba.

# %%
# código:
    
# función que saca todos los datos:
def datos(edad, promedio, estrato, genero, estado_civil, escolaridad, region):
    combinadas = [(edad[i], promedio[i], estrato[i], genero[i], estado_civil[i],\
                   escolaridad[i], region [i], i+1) for i in range(0, len(promedio))]
    
    dicc_ordenado = sorted(combinadas, key = lambda x: x[1], reverse = True)
    return dicc_ordenado

# Tupla con todos los datos
datos_c1 = datos (edad, promedio, estrato, genero, estado_civil, escolaridad, region)


# Creación tupla ordenada de estrato1
E1 = []
for i in datos_c1:
    if i[2] == 1:
        E1.append(i) 

# Creación tupla ordenada de estrato2
E2 = []
for i in datos_c1:
    if i[2] == 2:
        E2.append(i)


# Creación tupla ordenada de estrato3
E3 = []
for i in datos_c1:
    if i[2] == 3:
        E3.append(i)
        
# Creación tupla ordenada de estrato4
E4 = []
for i in datos_c1:
    if i[2] == 4:
        E4.append(i)
# Creación tupla ordenada de estrato5
E5 = []
for i in datos_c1:
    if i[2] == 5:
        E5.append(i)

#Total personas
totalpersonas = len(E1) + len(E2) + len(E3) + len(E4) + len(E5)


# >> EL VALOR 'BECAS' ES EDITABLE Y PERMITIRÁ QUE LOS STAKEHOLDERS DECIDAN CUANTAS BECAS OTORGAR.
# EL ALGORITMO SE AJUSTARÁ A EL VALOR AGREGADO EN ESTA VARIABLE
becas = 20

#Lista para almacenar valor de los becados
becadosC1 = []

## ASIGNACIÓN DE BECAS
while (becas >=1):   
    
    if len(becadosC1) == totalpersonas:
        print("Se han repartido el total de las becas")
        break
        
    else:
        cantidad_a_becar1 = mt.ceil(len(E1) * 0.02)
        while(cantidad_a_becar1 > 0 and becas >= 1):
            becadosC1.append(E1[0])
            E1.pop(0)
            cantidad_a_becar1 = cantidad_a_becar1-1
            becas = becas - 1 

        cantidad_a_becar2 = mt.ceil(len(E2) * 0.02)
        while(cantidad_a_becar2 > 0 and becas >= 1):
            becadosC1.append(E2[0])
            E2.pop(0)
            cantidad_a_becar2 = cantidad_a_becar2 -1
            becas = becas - 1

        cantidad_a_becar3 = mt.ceil(len(E3) * 0.02)
        while(cantidad_a_becar3 > 0 and becas >= 1):
            becadosC1.append(E3[0])
            E3.pop(0)
            cantidad_a_becar3 = cantidad_a_becar3 -1
            becas = becas - 1

        cantidad_a_becar4 = mt.ceil(len(E4) * 0.02)
        while(cantidad_a_becar4 > 0 and becas >= 1):
            becadosC1.append(E4[0])
            E4.pop(0)
            cantidad_a_becar4 = cantidad_a_becar4 -1
            becas = becas - 1

        cantidad_a_becar5 = mt.ceil(len(E5) * 0.02)
        while(cantidad_a_becar5 > 0 and becas >= 1):
            becadosC1.append(E5[0])
            E5.pop(0)
            cantidad_a_becar5 = cantidad_a_becar5 -1
            becas = becas - 1

# LISTA FINAL DE BECADOS
becadosC1
# Out:
# [(69, 5.0, 1, 'masculino', 'soltera', 'Secundaria', 'Pacifica', 377),
#  (47, 4.9, 1, 'masculino', 'casada', 'Secundaria', 'Andina', 163),
#  (32, 4.9, 1, 'femenino', 'casada', 'Secundaria', 'Pacifica', 364),
#  (59, 5.0, 2, 'femenino', 'divorciada', 'Secundaria', 'Caribe', 244),
#  (54, 4.9, 2, 'femenino', 'casada', 'Secundaria', 'Andina', 8),
#  (21, 4.9, 2, 'femenino', 'casada', 'Profesional', 'Andina', 208),
#  (59, 4.9, 2, 'masculino', 'casada', 'Profesional', 'Caribe', 492),
#  (75, 4.9, 3, 'femenino', 'casada', 'Primaria', 'Caribe', 61),
#  (21, 4.9, 3, 'masculino', 'soltera', 'Secundaria', 'Pacifica', 472),
#  (60, 4.7, 3, 'femenino', 'soltera', 'Profesional', 'Pacifica', 110),
#  (55, 4.6, 3, 'masculino', 'soltera', 'Profesional', 'Caribe', 160),
#  (69, 4.8, 4, 'masculino', 'divorciada', 'Profesional', 'Andina', 395),
#  (60, 4.8, 5, 'no binario', 'soltera', 'Secundaria', 'Andina', 260),
#  (28, 4.8, 1, 'no binario', 'divorciada', 'Secundaria', 'Andina', 284),
# ...

# %% [markdown]
# **Misión 5**
#
# Desarrollar un algoritmo que permita conocer la población que sería becada según los criterios propuestos por el *segundo grupo* mencionado arriba.

# %%
# código

#Tupla principal para el desarrollo de este problema donde se alamcenan los datos necesarios
Todos = datos(edad, promedio, estrato, genero, estado_civil, escolaridad, region)
Todos

#Listas donde se guardarán los estudiantes becados
andina_masculino_becados = []
andina_femenino_becados = []
andina_no_binario_becados = []
andina_otro_becados = []
caribe_masculino_becados = []
caribe_femenino_becados = []
caribe_no_binario_becados = []
caribe_otro_becados = []
pacifica_masculino_becados = [] 
pacifica_femenino_becados = []
pacifica_no_binario_becados = []
pacifica_otro_becados = []
orinoquia_masculino_becados = []
orinoquia_femenino_becados = []
orinoquia_no_binario_becados = []
orinoquia_otro_becados = []
amazonia_masculino_becados = []
amazonia_femenino_becados = []
amazonia_no_binario_becados = []
amazonia_otro_becados = []
    
# CANTIDAD DE BECAS A ENTREGAR:
becas = 20

andina_masculino = []
andina_femenino = []
andina_no_binario = []
andina_otro = []

caribe_masculino = []
caribe_femenino = []
caribe_no_binario = []
caribe_otro = []

pacifica_masculino = []
pacifica_femenino = []
pacifica_no_binario = []
pacifica_otro = []

orinoquia_masculino = []
orinoquia_femenino = []
orinoquia_no_binario = []
orinoquia_otro = []

amazonia_masculino = []
amazonia_femenino = []
amazonia_no_binario = []
amazonia_otro = []

#Separación de los datos en listas que tengan categorias con sus niveles
for i in Todos:
    if i[6] == "Andina" and i[3] == 'femenino' :
        andina_femenino.append(i)
        
for i in Todos:
    if i[6] == "Andina" and i[3] == 'masculino' :
        andina_masculino.append(i)

for i in Todos:
    if i[6] == "Andina" and i[3] == 'otro' :
        andina_otro.append(i)

for i in Todos:
    if i[6] == "Andina" and i[3] == 'no binario' :
        andina_no_binario.append(i)
        
for i in Todos:
    if i[6] == "Caribe" and i[3] == 'femenino' :
        caribe_femenino.append(i)
        
for i in Todos:
    if i[6] == "Caribe" and i[3] == 'masculino' :
        caribe_masculino.append(i)

for i in Todos:
    if i[6] == "Caribe" and i[3] == 'otro' :
        caribe_otro.append(i)

for i in Todos:
    if i[6] == "Caribe" and i[3] == 'no binario' :
        caribe_no_binario.append(i)

for i in Todos:
    if i[6] == "Pacifica" and i[3] == 'femenino' :
        pacifica_femenino.append(i)
        
for i in Todos:
    if i[6] == "Pacifica" and i[3] == 'masculino' :
        pacifica_masculino.append(i)

for i in Todos:
    if i[6] == "Pacifica" and i[3] == 'otro' :
        pacifica_otro.append(i)

for i in Todos:
    if i[6] == "Pacifica" and i[3] == 'no binario' :
        pacifica_no_binario.append(i)
        
for i in Todos:
    if i[6] == "Orinoquia" and i[3] == 'femenino' :
        orinoquia_femenino.append(i)
        
for i in Todos:
    if i[6] == "Orinoquia" and i[3] == 'masculino' :
        orinoquia_masculino.append(i)

for i in Todos:
    if i[6] == "Orinoquia" and i[3] == 'otro' :
        orinoquia_otro.append(i)

for i in Todos:
    if i[6] == "Orinoquia" and i[3] == 'no binario' :
        orinoquia_no_binario.append(i)
        
for i in Todos:
    if i[6] == "Amazonia" and i[3] == 'femenino' :
        amazonia_femenino.append(i)
        
for i in Todos:
    if i[6] == "Amazonia" and i[3] == 'masculino' :
        amazonia_masculino.append(i)

for i in Todos:
    if i[6] == "Amazonia" and i[3] == 'otro' :
        amazonia_otro.append(i)

for i in Todos:
    if i[6] == "Amazonia" and i[3] == 'no binario' :
        amazonia_no_binario.append(i)
    
# CANTIDAD DE BECAS SEGÚN REGIÓN Y GÉNERO
becas_por_grupo = int(becas/20)

#LISTA DE BECADOS
becadosC2 = []

#Asignación de becas
for i in range(1, becas_por_grupo+1):
    if i <= len(andina_masculino):
        andina_masculino_becados.append(andina_masculino[i-1])
        becadosC2.append(andina_masculino_becados[i-1])
    if i <= len(andina_femenino):
        andina_femenino_becados.append(andina_femenino[i-1])
        becadosC2.append(andina_femenino_becados[i-1])
    if i <= len(andina_no_binario):
        andina_no_binario_becados.append(andina_no_binario[i-1])
        becadosC2.append(andina_no_binario_becados[i-1])
    if i <= len(andina_otro):
        andina_otro_becados.append(andina_otro[i-1])
        becadosC2.append(andina_otro_becados[i-1])
    if i <= len(caribe_masculino):    
        caribe_masculino_becados.append(caribe_masculino[i-1])
        becadosC2.append(caribe_masculino_becados[i-1])
    if i <= len(caribe_femenino):  
        caribe_femenino_becados.append(caribe_femenino[i-1])
        becadosC2.append(caribe_femenino_becados[i-1])
    if i <= len(caribe_no_binario):  
        caribe_no_binario_becados.append(caribe_no_binario[i-1])
        becadosC2.append(caribe_no_binario_becados[i-1])
    if i <= len(caribe_otro):  
        caribe_otro_becados.append(caribe_otro[i-1])
        becadosC2.append(caribe_otro_becados[i-1])
    if i <= len(pacifica_masculino):  
        pacifica_masculino_becados.append(pacifica_masculino[i-1])
        becadosC2.append(pacifica_masculino_becados[i-1])
    if i <= len(pacifica_femenino):
        pacifica_femenino_becados.append(pacifica_femenino[i-1])
        becadosC2.append(pacifica_femenino_becados[i-1])
    if i <= len(pacifica_no_binario):
        pacifica_no_binario_becados.append(pacifica_no_binario[i-1])
        becadosC2.append(pacifica_no_binario_becados[i-1])
    if i <= len(pacifica_otro):
        pacifica_otro_becados.append(pacifica_otro[i-1])
        becadosC2.append(pacifica_otro_becados[i-1])
    if i <= len(orinoquia_masculino):
        orinoquia_masculino_becados.append(orinoquia_masculino[i-1])
        becadosC2.append(orinoquia_masculino_becados[i-1])
    if i <= len(orinoquia_femenino):
        orinoquia_femenino_becados.append(orinoquia_femenino[i-1])
        becadosC2.append(orinoquia_femenino_becados[i-1])
    if i <= len(orinoquia_no_binario):
        orinoquia_no_binario_becados.append(orinoquia_no_binario[i-1])
        becadosC2.append(orinoquia_no_binario_becados[i-1])
    if i <= len(orinoquia_otro):
        orinoquia_otro_becados.append(orinoquia_otro[i-1])
        becadosC2.append(orinoquia_otro_becados[i-1])
    if i <= len(amazonia_masculino):    
        amazonia_masculino_becados.append(amazonia_masculino[i-1])
        becadosC2.append(amazonia_masculino_becados[i-1])
    if i <= len(amazonia_femenino): 
        amazonia_femenino_becados.append(amazonia_femenino[i-1])
        becadosC2.append(amazonia_femenino_becados[i-1])
    if i <= len(amazonia_no_binario): 
        amazonia_no_binario_becados.append(amazonia_no_binario[i-1])
        becadosC2.append(amazonia_no_binario_becados[i-1])
    if i <= len(amazonia_otro): 
        amazonia_otro_becados.append(amazonia_otro[i-1])
        becadosC2.append(amazonia_otro_becados[i-1])

#Lista final de becados
becadosC2
# Out:
# [(47, 4.9, 1, 'masculino', 'casada', 'Secundaria', 'Andina', 163),
#  (54, 4.9, 2, 'femenino', 'casada', 'Secundaria', 'Andina', 8),
#  (60, 4.8, 5, 'no binario', 'soltera', 'Secundaria', 'Andina', 260),
#  (34, 2.4, 3, 'otro', 'soltera', 'Secundaria', 'Andina', 374),
#  (59, 4.9, 2, 'masculino', 'casada', 'Profesional', 'Caribe', 492),
#  (59, 5.0, 2, 'femenino', 'divorciada', 'Secundaria', 'Caribe', 244),
#  (51, 4.3, 2, 'no binario', 'casada', 'Secundaria', 'Caribe', 23),
#  (60, 3.6, 2, 'otro', 'soltera', 'Secundaria', 'Caribe', 137),
#  (69, 5.0, 1, 'masculino', 'soltera', 'Secundaria', 'Pacifica', 377),
#  (32, 4.9, 1, 'femenino', 'casada', 'Secundaria', 'Pacifica', 364),
#  (73, 4.0, 1, 'no binario', 'divorciada', 'Profesional', 'Pacifica', 362),
#  (50, 4.2, 1, 'masculino', 'soltera', 'Secundaria', 'Orinoquia', 423),
#  (57, 3.9, 2, 'femenino', 'divorciada', 'Profesional', 'Orinoquia', 114),
#  (26, 2.1, 2, 'otro', 'divorciada', 'Secundaria', 'Orinoquia', 5),
# ...

# %% [markdown]
# **Misión 6**
#
# Desarrollar un algoritmo, a partir de lo anterior, cuyo resultado permita al comité comparar fácilmente las características de las dos poblaciones hipotéticas que recibirían becas.
#
# *Ayuda*: considera utilizar tus implementaciones de la *Misión 2* para facilitar esta misión.

# %%
# código
estadisticas_estrato(becadosC1, becadosC2)
print("")
estadisticas_edad(becadosC1, becadosC2)
print("")
print("A continuación se muestran las diferencias entre estrato, región y género para cada política")
graficas(becadosC1, becadosC2)
print("")
print("")
print("El siguiente es un histograma de promedio para la política 1")
hist_promedio(becadosC1,1)
# Out:
# A continuación se muestran los valores estadísticos para la variable estrato según las dos políticas
#
# Primera política:
# Mediana: 2
# Desviación estándar: 1.061838029079765
# Moda: 1.061838029079765
#
# Segunda política:
# Mediana: 2
# Desviación estándar: 1.0671873729054748
# Moda: 1.0671873729054748
#
# A continuación se muestran los valores estadísticos para la variable edad según las dos políticas
#
# Primera política:
# Mediana: 54
# Desviación estándar: 17.52455420260384
# Moda: 69
#
# Segunda política:
# Mediana: 51
# Desviación estándar: 17.224731000067646
# Moda: 60
#
# A continuación se muestran las diferencias entre estrato, región y género para cada política
# El siguiente es un histograma de promedio para la política 1
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 3. Desarrollo de una solución analítica
#
# Reconociendo la complejidad de este problema (que no permite reducirlo a una dicotomía) y viendo el potencial del análisis de datos para enriquecer la discusión y los insumos para tomar decisiones, el comité ha solicitado una herramienta analítica que les permita . Sus requerimientos son:
#
# * La herramienta debe permitir ingresar una política de selección de becados.
#     * Se debe poder elegir el rango de edad de los aspirantes.
#     * Se debe poder elegir qué proporción de las becas se asigna a cada género, a cada estrato, o a cada región (pero sólo debe elegirse uno de estos criterios).
# * La herramienta debe generar un resultado que permita al comité analizar las características de la población potencialmente elegida si se usara la política ingresada.
#
# **Misión 7**
#
# Desarrollar, a partir de lo construido hasta el momento, un algoritmo que permita cumplir con los requerimientos del comité.

# %%
# código

#Función que genera una tupla con la información que se utilizará para la asignación de becas
def datos_7(edad, promedio, estrato, genero, estado_civil, escolaridad, region,criterio):
    combinadas = [(edad[i], promedio[i], estrato[i], genero[i], estado_civil[i],\
                   escolaridad[i], region [i], criterio[i], i+1) for i in range(0, len(promedio))]
    
    dicc_ordenado = sorted(combinadas, key = lambda x: x[1], reverse = True)
    return dicc_ordenado

#Aquí el cliente pordrá ingresar rango de edad
menor = 50
mayor = 70

#Lista donde se guardarán los estudiantes becados
becados = []

#Aquí el cliente deberá escoger el criterio para la asignación de becas. Los únicos valores permitidos
#son: genero, estrato o region
criterio = estrato

#Aquí se cargan los datos con el criterio elegido
datos = datos_7(edad, promedio, estrato, genero, estado_civil, escolaridad, region, criterio)

#TOTAL BECAS A ENTREGAR
becas = 10

#Proporciones: porcentajes según las categorías del criterio. La suma tiene que ser igual a 1
#EN CASO DE ESCOGER GENERO SE TIENEN QUE DISTRIBUIR LAS PROPORCIONES AQUÍ
masculino = 0
femenino = 0
otro = 0
no_binario = 0

#EN CASO DE ESCOGER ESTRATO SE TIENEN QUE DISTRIBUIR LAS PROPORCIONES AQUÍ
est1 = 0.2
est2 = 0.4
est3 = 0.5
est4 = 0.1
est5 = 0.1

#EN CASO DE ESCOGER REGIÓN SE TIENEN QUE DISTRIBUIR LAS PROPORCIONES AQUÍ
reg_andina = 0.2
reg_pacifica = 0.1
reg_orinoquia = 0.3
reg_caribe = 0.3
reg_amazonia = 0.1

#Asignación de becas con criterio región
if criterio == region:
    
        becas_andina = int(becas*reg_andina)
        becas_pacifica = int(becas*reg_pacifica)
        becas_orinoquia = int(becas*reg_orinoquia)
        becas_caribe = int(becas*reg_caribe)
        becas_amazonia = int(becas*reg_amazonia)

        for i in datos:
            if i[0] > menor and i[0] < mayor and i[6] == "Andina" and becas_andina >0:
                becados.append(i)
                becas_andina = becas_andina -1


        for i in datos:
            if i[0] > menor and i[0] < mayor and i[6] == "Pacifica" and becas_pacifica >0:
                becados.append(i)         
                becas_pacifica = becas_pacifica -1


        for i in datos:
             if i[0] > menor and i[0] < mayor and i[6] == "Orinoquia" and becas_orinoquia >0:
                becados.append(i)
                becas_orinoquia = becas_orinoquia -1


        for i in datos:
            if i[0] > menor and i[0] < mayor and i[6] == "Caribe" and becas_caribe >0:
                becados.append(i) 
                becas_caribe = becas_caribe -1


        for i in datos:
            if i[0] > menor and i[0] < mayor and i[6] == "Amazonia" and becas_amazonia>0:
                becados.append(i) 
                becas_amazonia = becas_amazonia -1

#Asignación de becas con criterio estrato
elif criterio == estrato:
    
        becas_est1 = int(becas*est1)
        becas_est2 = int(becas*est2)
        becas_est3 = int(becas*est3)
        becas_est4 = int(becas*est4)
        becas_est5 = int(becas*est5)

        for i in datos:
            if i[0] > menor and i[0] < mayor and i[2] == 1 and becas_est1 >0:
                becados.append(i)
                becas_est1 = becas_est1 -1


        for i in datos:
            if i[0] > menor and i[0] < mayor and i[2] == 2 and becas_est2 >0:
                becados.append(i)         
                becas_est2 = becas_est2 -1


        for i in datos:
             if i[0] > menor and i[0] < mayor and i[2] == 3 and becas_est3 >0:
                becados.append(i)
                becas_est3 = becas_est3 -1


        for i in datos:
            if i[0] > menor and i[0] < mayor and i[2] == 4 and becas_est4 >0:
                becados.append(i) 
                becas_est4 = becas_est4 -1


        for i in datos:
            if i[0] > menor and i[0] < mayor and i[2] == 5 and becas_est5>0:
                becados.append(i) 
                becas_est5 = becas_est5 -1

#Asignación de becas con criterio genero
elif criterio == genero:

        becas_masc = int(becas*masculino)
        becas_fem = int(becas*femenino)
        becas_otro = int(becas*otro)
        becas_nobi = int(becas*no_binario)

        for i in datos:
            if i[0] > menor and i[0] < mayor and i[3] == "masculino" and becas_masc >0:
                becados.append(i)
                becas_masc = becas_masc-1


        for i in datos:
            if i[0] > menor and i[0] < mayor and i[3] == "femenino" and becas_fem >0:
                becados.append(i)         
                becas_fem = becas_fem -1


        for i in datos:
             if i[0] > menor and i[0] < mayor and i[3] == "otro" and becas_otro >0:
                becados.append(i)
                becas_otro = becas_otro -1


        for i in datos:
            if i[0] > menor and i[0] < mayor and i[3] == "no binario" and becas_nobi >0:
                becados.append(i) 
                becas_nobi = becas_nobi -1


        for i in datos:
            if i[0] > menor and i[0] < mayor and i[2] == 5 and becas_est5>0:
                becados.append(i) 
                becas_est5 = becas_est5 -1
becados
# Out:
# [(69, 5.0, 1, 'masculino', 'soltera', 'Secundaria', 'Pacifica', 1, 377),
#  (52, 4.3, 1, 'masculino', 'casada', 'Secundaria', 'Andina', 1, 399),
#  (59, 5.0, 2, 'femenino', 'divorciada', 'Secundaria', 'Caribe', 2, 244),
#  (54, 4.9, 2, 'femenino', 'casada', 'Secundaria', 'Andina', 2, 8),
#  (59, 4.9, 2, 'masculino', 'casada', 'Profesional', 'Caribe', 2, 492),
#  (58, 4.5, 2, 'femenino', 'divorciada', 'Secundaria', 'Andina', 2, 410),
#  (60, 4.7, 3, 'femenino', 'soltera', 'Profesional', 'Pacifica', 3, 110),
#  (55, 4.6, 3, 'masculino', 'soltera', 'Profesional', 'Caribe', 3, 160),
#  (56, 4.2, 3, 'femenino', 'casada', 'Secundaria', 'Caribe', 3, 257),
#  (54, 4.2, 3, 'masculino', 'casada', 'Profesional', 'Andina', 3, 429),
#  (54, 4.1, 3, 'femenino', 'casada', 'Secundaria', 'Andina', 3, 46),
#  (69, 4.8, 4, 'masculino', 'divorciada', 'Profesional', 'Andina', 4, 395),
#  (60, 4.8, 5, 'no binario', 'soltera', 'Secundaria', 'Andina', 5, 260)]

# %% [markdown]
# **Misión 8**
#
# Proponer, con base en tu propio uso de la herramienta, una política de ingreso que consideres apropiada dado el contexto proporcionado. Si lo crees adecuado, explica, máximo 500 caracteres, las virtudes de tu propuesta (esto puede estar soportado en los datos, o no).

# %%
# respuesta en texto (solo leeremos los primeros 300 caracteres de la respuesta)

respuesta = 'Debido a que las becas deben ser otorgadas a quienes más necesitan los recursos, basaré mi política en los estratos sociales. Le asignare pesos mayores a los estratos mas bajos entendiendo que se le brinda recursos a quien más los necesita. El rango de edad (35 y 73) se escoge con base en los resultados de las dos políticas iniciales'

# %% [markdown]
# **Misión 9**
#
# Ejecutar el algoritmo desarrollado en la *Misión 7* sobre la política que sugieres proponer al comité. Explicar claramente tus conlusiones con el soporte de los resultados de la herramienta.

# %%
# código
#Rango de edad
menor = 35
mayor = 73

#Lista donde se guardarán los estudiantes becados
becados = []

#Aquí el cliente deberá escoger el criterio para la asignación de becas. Los únicos valores permitidos
#son: genero, estrato o region
criterio = estrato

#Aquí se cargan los datos con el criterio elegido
datos = datos_7(edad, promedio, estrato, genero, estado_civil, escolaridad, region, criterio)

#TOTAL BECAS A ENTREGAR
becas = 30
#Parámetros de pesos
est1 = 0.3
est2 = 0.4
est3 = 0.2
est4 = 0.1
est5 = 0.0

#Asignación de becas
if criterio == estrato:
    
        becas_est1 = int(becas*est1)
        becas_est2 = int(becas*est2)
        becas_est3 = int(becas*est3)
        becas_est4 = int(becas*est4)
        becas_est5 = int(becas*est5)

        for i in datos:
            if i[0] > menor and i[0] < mayor and i[2] == 1 and becas_est1 >0:
                becados.append(i)
                becas_est1 = becas_est1 -1


        for i in datos:
            if i[0] > menor and i[0] < mayor and i[2] == 2 and becas_est2 >0:
                becados.append(i)         
                becas_est2 = becas_est2 -1


        for i in datos:
             if i[0] > menor and i[0] < mayor and i[2] == 3 and becas_est3 >0:
                becados.append(i)
                becas_est3 = becas_est3 -1


        for i in datos:
            if i[0] > menor and i[0] < mayor and i[2] == 4 and becas_est4 >0:
                becados.append(i) 
                becas_est4 = becas_est4 -1


        for i in datos:
            if i[0] > menor and i[0] < mayor and i[2] == 5 and becas_est5>0:
                becados.append(i) 
                becas_est5 = becas_est5 -1


print("LAS SIGUIENTES GRÁFICAS Y DATOS MUESTRAN COMPARACIONES ENTRE LA POLÍTICA SELECCIONADA (POLÍTICA1) Y LA POLÍTICA DEL NUMERAL 4 (POLÍTICA2)")
print("")
print("")
estadisticas_estrato(becados, becadosC1)
print("")
estadisticas_edad(becados, becadosC1)
print("")
print("A continuación se muestran las diferencias entre estrato, región y género para cada política")
graficas(becados, becadosC1)
print("")
print("")
print("El siguiente es un histograma de promedio para la política 1")
hist_promedio(becados,1)


conclusion = 'Se ven resultados muy interesantes. En primer lugar, la desviación estándar de la edad se reduce a la mitad y su mediana y moda se acotan entre 54 y 56 años (moda inferior en 15 años). Esto quiere decir que en efecto se le está brindando ayuda a gente más joven, quizás con mayores dificultades. La distribución entre género es equitativa, dando más becas a personas femeninas. La región más favorecida es la región Caribe. Esto quiere decir que gran parte de la población de estratos bajos se encuentra en esta región. La diferencia con la política anterior es muy notable, lo que puede mostrar una relación entre recursos y promedio académico. Todo indica que la falta de recursos de la región ha causado que los promedios sean bajos, razón por la cual en las políticas anteriores no recibían tantas becas.'
conclusion
# Out:
# LAS SIGUIENTES GRÁFICAS Y DATOS MUESTRAN COMPARACIONES ENTRE LA POLÍTICA SELECCIONADA (POLÍTICA1) Y LA POLÍTICA DEL NUMERAL 4 (POLÍTICA2)
#
#
# A continuación se muestran los valores estadísticos para la variable estrato según las dos políticas
#
# Primera política:
# Mediana: 2
# Desviación estándar: 0.9433981132056605
# Moda: 0.9433981132056605
#
# Segunda política:
# Mediana: 2
# Desviación estándar: 1.061838029079765
# Moda: 1.061838029079765
#
# A continuación se muestran los valores estadísticos para la variable edad según las dos políticas
#
# Primera política:
# Mediana: 56
# Desviación estándar: 8.71397345264107
# Moda: 54
#
# Segunda política:
# Mediana: 54
# Desviación estándar: 17.52455420260384
# Moda: 69
#
# A continuación se muestran las diferencias entre estrato, región y género para cada política
# El siguiente es un histograma de promedio para la política 1
# ...

# %% [markdown]
# ## Referencias
# * Discriminación Positiva<br>
# https://es.wikipedia.org/wiki/Discriminaci%C3%B3n_positiva
# * Análisis de formulación del programa “Ser Pilo Paga”<br>
# https://repository.urosario.edu.co/handle/10336/12526
# * La acción afirmativa en la Universidad de los Andes: El caso del programa "Oportunidades para talentos nacionales"<br> http://www.scielo.org.co/scielo.php?script=sci_arttext&pid=S0123-885X2004000300005
# * Acción afirmativa y equidad: un análisis desde la propuesta de Thomas Nagel<br>
# http://www.scielo.org.mx/scielo.php?script=sci_arttext&pid=S2007-24062016000200049

# %% [markdown]
# ## Créditos

# %% [markdown]
# Camilo Gómez - 11/06/21<br>
# *Revisado*: 25/08/21
